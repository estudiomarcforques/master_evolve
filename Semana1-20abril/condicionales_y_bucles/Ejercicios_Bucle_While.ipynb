# %% [markdown]
# ## 🧾 Ejercicios `while` con contexto de negocio
#
# ---
#
# ### 1️⃣ Calcular el total de ventas del día
#
# #### Objetivo:
# Un comercio registra sus ventas una a una. El programa debe permitir al usuario ingresar el valor de cada venta.
# El proceso termina cuando se introduce un valor de venta igual a `0`. Al final, se muestra el total acumulado.

# %%
total_ventas = 0

while ventas != 0:
    ventas  = float(input("Ingresa el monto de la venta (o 0 para terminar): "))
    total_ventas += ventas


print(f"El total de ventas es: {total_ventas}")
# Out:
# El total de ventas es: 179.6

# %% [markdown]
# ### 2️⃣ Registrar pagos hasta alcanzar una meta
#
# #### Objetivo:
# Una tienda necesita recaudar al menos **500 euros** en el día.
# Cada cliente paga una cantidad y se va sumando al total.
# El programa debe seguir pidiendo montos hasta que se alcance (o supere) la meta.
# Al final, muestra cuánto se recaudó y cuántos pagos fueron necesarios.

# %%
total_recaudado = 0
pagos = 0
meta = 500

while total_recaudado < meta:
    pago = float(input("Ingresa el monto del pago: "))
    total_recaudado += pago
    pagos += 1

print(f"Se alcanzó la meta con {pagos} pagos.")
print(f"Total recaudado: {total_recaudado}")

# %% [markdown]
# ### 3️⃣ Control de stock de productos
# ##### Objetivo:
# Un sistema de inventario debe restar unidades del stock cada vez que hay una venta.
# El stock inicial es 20. En cada iteración, se ingresa cuántas unidades se vendieron.
# El bucle se detiene cuando no queda stock suficiente para cubrir la venta.

# %%
stock = 20

while stock > 0:
    venta = int(input("Ingresa la cantidad de productos vendidos: "))
    if venta > stock:
        print(f"No hay suficiente stock. Solo quedan {stock} productos.")
    else:
        stock -= venta
        print(f"Venta registrada. Stock restante: {stock}")
# Out:
# No hay suficiente stock. Solo quedan 20 productos.
# No hay suficiente stock. Solo quedan 20 productos.
# Venta registrada. Stock restante: 17
# No hay suficiente stock. Solo quedan 17 productos.
# Venta registrada. Stock restante: 12
# Venta registrada. Stock restante: 6
# No hay suficiente stock. Solo quedan 6 productos.
# Venta registrada. Stock restante: 0

# %% [markdown]
# ### 4️⃣ Registrar empleados hasta llegar al límite
# ##### Objetivo:
# Una empresa va registrando empleados nuevos. El sistema pide el nombre de cada uno.
# Solo se pueden registrar hasta 10 empleados. Cuando se llega a ese número, se detiene el registro y se imprime cuántos se registraron en total.

# %%
empleados_registrados = 0

while empleados_registrados < 10:
    nombre = input("Nombre del empleado: ")
    empleados_registrados += 1
    print(f"Empleado {nombre} registrado. Total empleados: {empleados_registrados}")
# Out:
# Empleado paco loco registrado. Total empleados: 1
# Empleado gfh registrado. Total empleados: 2
# Empleado dfg registrado. Total empleados: 3
# Empleado h registrado. Total empleados: 4
# Empleado dfgh registrado. Total empleados: 5
# Empleado hdfg registrado. Total empleados: 6
# Empleado dfg registrado. Total empleados: 7
# Empleado dfgh registrado. Total empleados: 8
# Empleado dfghh registrado. Total empleados: 9
# Empleado dfgh registrado. Total empleados: 10
